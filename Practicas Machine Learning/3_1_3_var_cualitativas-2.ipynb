# %% [markdown]
# ![logo](img/logoitqv1.jpg)
# <br>
# # 0.1 PAO26-26 - Python 101, Variables Cualitativas
# <br>
#
# ![python](img/python_logo.png)
#
# <br>
#
# *Kenin CUsme*
#
# <br>
#
# [link de Git Hub](https://github.com/kenin395/Machine-Learning.git)

# %%
# Creación aleatoria de datos
import numpy as np
import random
random.seed(42)

# %%
# Crear una lista vacía para almacenar los niveles de estudios
nivel_estudios = []

# Agregar 110 registros con el valor "Secundaria"
nivel_estudios.extend(['Secundaria'] * 110)

# Agregar 172 registros con el valor "Bachillerato"
nivel_estudios.extend(['Bachillerato'] * 172)

# Agregar 145 registros con el valor "Grado"
nivel_estudios.extend(['Grado'] * 145)

# Agregar 52 registros con el valor "Master"
nivel_estudios.extend(['Master'] * 52)

# Agregar 21 registros con el valor "Doctorado"
nivel_estudios.extend(['Doctorado'] * 21)

# Mezclar aleatoriamente el orden de todos los niveles de estudio
# para que no queden agrupados por categoría
nivel_estudios = np.random.permutation(nivel_estudios)

# %%
print(nivel_estudios)
# Out:
# ['Secundaria' 'Bachillerato' 'Secundaria' 'Grado' 'Grado' 'Secundaria'
#  'Master' 'Bachillerato' 'Bachillerato' 'Master' 'Secundaria' 'Grado'
#  'Master' 'Bachillerato' 'Grado' 'Grado' 'Master' 'Secundaria' 'Grado'
#  'Grado' 'Master' 'Master' 'Bachillerato' 'Master' 'Grado' 'Secundaria'
#  'Master' 'Grado' 'Bachillerato' 'Bachillerato' 'Secundaria'
#  'Bachillerato' 'Grado' 'Grado' 'Grado' 'Bachillerato' 'Bachillerato'
#  'Bachillerato' 'Secundaria' 'Bachillerato' 'Bachillerato' 'Bachillerato'
#  'Master' 'Bachillerato' 'Bachillerato' 'Grado' 'Grado' 'Bachillerato'
#  'Bachillerato' 'Secundaria' 'Bachillerato' 'Secundaria' 'Grado'
#  'Bachillerato' 'Grado' 'Grado' 'Master' 'Bachillerato' 'Grado' 'Grado'
#  'Grado' 'Doctorado' 'Bachillerato' 'Grado' 'Secundaria' 'Bachillerato'
#  'Master' 'Grado' 'Bachillerato' 'Grado' 'Bachillerato' 'Grado' 'Grado'
#  'Grado' 'Bachillerato' 'Bachillerato' 'Doctorado' 'Bachillerato' 'Grado'
#  'Bachillerato' 'Secundaria' 'Grado' 'Secundaria' 'Grado' 'Bachillerato'
#  'Secundaria' 'Grado' 'Bachillerato' 'Secundaria' 'Bachillerato'
#  'Secundaria' 'Bachillerato' 'Secundaria' 'Grado' 'Bachillerato'
#  'Secundaria' 'Secundaria' 'Grado' 'Bachillerato' 'Master' 'Secundaria'
#  'Master' 'Bachillerato' 'Secundaria' 'Doctorado' 'Bachillerato'
#  'Bachillerato' 'Doctorado' 'Secundaria' 'Secundaria' 'Bachillerato'
#  'Bachillerato' 'Grado' 'Secundaria' 'Bachillerato' 'Doctorado'
#  'Bachillerato' 'Secundaria' 'Secundaria' 'Master' 'Grado' 'Secundaria'
#  'Master' 'Grado' 'Bachillerato' 'Master' 'Grado' 'Grado' 'Grado'
#  'Bachillerato' 'Grado' 'Bachillerato' 'Doctorado' 'Grado' 'Bachillerato'
#  'Grado' 'Bachillerato' 'Master' 'Bachillerato' 'Master' 'Bachillerato'
#  'Master' 'Secundaria' 'Grado' 'Bachillerato' 'Bachillerato' 'Grado'
#  'Secundaria' 'Grado' 'Secundaria' 'Bachillerato' 'Grado' 'Doctorado'
#  'Secundaria' 'Grado' 'Grado' 'Secundaria' 'Master' 'Bachillerato'
#  'Master' 'Bachillerato' 'Bachillerato' 'Grado' 'Grado' 'Grado' 'Grado'
#  'Secundaria' 'Secundaria' 'Grado' 'Grado' 'Secundaria' 'Bachillerato'
#  'Bachillerato' 'Grado' 'Master' 'Grado' 'Grado' 'Doctorado' 'Grado'
#  'Secundaria' 'Bachillerato' 'Secundaria' 'Master' 'Secundaria'
#  'Secundaria' 'Grado' 'Grado' 'Bachillerato' 'Bachillerato' 'Grado'
#  'Bachillerato' 'Grado' 'Secundaria' 'Bachillerato' 'Bachillerato' 'Grado'
#  'Bachillerato' 'Bachillerato' 'Secundaria' 'Grado' 'Secundaria'
#  'Bachillerato' 'Grado' 'Doctorado' 'Grado' 'Grado' 'Bachillerato'
#  'Bachillerato' 'Bachillerato' 'Grado' 'Grado' 'Master' 'Doctorado'
#  'Grado' 'Bachillerato' 'Bachillerato' 'Secundaria' 'Bachillerato'
#  'Secundaria' 'Bachillerato' 'Master' 'Master' 'Secundaria' 'Secundaria'
#  'Bachillerato' 'Master' 'Master' 'Grado' 'Master' 'Bachillerato'
#  'Secundaria' 'Bachillerato' 'Grado' 'Secundaria' 'Secundaria'
#  'Bachillerato' 'Bachillerato' 'Grado' 'Bachillerato' 'Grado' 'Grado'
#  'Secundaria' 'Bachillerato' 'Grado' 'Grado' 'Grado' 'Doctorado' 'Grado'
#  'Bachillerato' 'Grado' 'Secundaria' 'Bachillerato' 'Grado' 'Bachillerato'
#  'Bachillerato' 'Secundaria' 'Grado' 'Grado' 'Bachillerato' 'Secundaria'
#  'Master' 'Bachillerato' 'Grado' 'Secundaria' 'Grado' 'Grado' 'Grado'
#  'Bachillerato' 'Grado' 'Bachillerato' 'Bachillerato' 'Bachillerato'
#  'Bachillerato' 'Master' 'Doctorado' 'Master' 'Bachillerato' 'Grado'
#  'Bachillerato' 'Secundaria' 'Bachillerato' 'Secundaria' 'Bachillerato'
#  'Grado' 'Bachillerato' 'Bachillerato' 'Grado' 'Bachillerato' 'Grado'
#  'Grado' 'Grado' 'Doctorado' 'Secundaria' 'Grado' 'Bachillerato'
#  'Bachillerato' 'Grado' 'Bachillerato' 'Secundaria' 'Secundaria' 'Grado'
#  'Bachillerato' 'Secundaria' 'Master' 'Secundaria' 'Secundaria'
#  'Bachillerato' 'Secundaria' 'Bachillerato' 'Secundaria' 'Grado' 'Grado'
#  'Master' 'Grado' 'Bachillerato' 'Bachillerato' 'Grado' 'Grado' 'Grado'
#  'Grado' 'Bachillerato' 'Grado' 'Bachillerato' 'Master' 'Bachillerato'
#  'Secundaria' 'Secundaria' 'Grado' 'Bachillerato' 'Bachillerato'
#  'Bachillerato' 'Bachillerato' 'Grado' 'Secundaria' 'Secundaria'
#  'Secundaria' 'Secundaria' 'Grado' 'Secundaria' 'Grado' 'Grado'
#  'Secundaria' 'Bachillerato' 'Bachillerato' 'Bachillerato' 'Bachillerato'
#  'Bachillerato' 'Secundaria' 'Secundaria' 'Grado' 'Bachillerato'
#  'Bachillerato' 'Secundaria' 'Bachillerato' 'Grado' 'Master' 'Master'
#  'Secundaria' 'Bachillerato' 'Master' 'Secundaria' 'Bachillerato'
#  'Bachillerato' 'Master' 'Secundaria' 'Secundaria' 'Grado' 'Master'
#  'Secundaria' 'Secundaria' 'Grado' 'Secundaria' 'Bachillerato'
#  'Bachillerato' 'Grado' 'Grado' 'Grado' 'Bachillerato' 'Bachillerato'
#  'Bachillerato' 'Bachillerato' 'Master' 'Bachillerato' 'Bachillerato'
#  'Secundaria' 'Grado' 'Secundaria' 'Bachillerato' 'Secundaria'
#  'Bachillerato' 'Master' 'Grado' 'Secundaria' 'Bachillerato' 'Grado'
#  'Master' 'Secundaria' 'Bachillerato' 'Secundaria' 'Secundaria'
#  'Bachillerato' 'Grado' 'Doctorado' 'Secundaria' 'Bachillerato'
#  'Secundaria' 'Secundaria' 'Secundaria' 'Bachillerato' 'Master' 'Grado'
#  'Secundaria' 'Grado' 'Master' 'Grado' 'Master' 'Doctorado' 'Grado'
#  'Bachillerato' 'Secundaria' 'Grado' 'Bachillerato' 'Master' 'Grado'
#  'Bachillerato' 'Bachillerato' 'Secundaria' 'Master' 'Bachillerato'
#  'Secundaria' 'Bachillerato' 'Bachillerato' 'Doctorado' 'Secundaria'
#  'Doctorado' 'Bachillerato' 'Grado' 'Secundaria' 'Grado' 'Bachillerato'
#  'Secundaria' 'Bachillerato' 'Grado' 'Bachillerato' 'Bachillerato' 'Grado'
#  'Bachillerato' 'Secundaria' 'Bachillerato' 'Grado' 'Grado' 'Bachillerato'
#  'Secundaria' 'Grado' 'Grado' 'Bachillerato' 'Grado' 'Bachillerato'
#  'Grado' 'Bachillerato' 'Grado' 'Bachillerato' 'Bachillerato' 'Master'
#  'Bachillerato' 'Bachillerato' 'Secundaria' 'Grado' 'Bachillerato'
#  'Secundaria' 'Secundaria' 'Bachillerato' 'Grado' 'Grado' 'Secundaria'
#  'Secundaria' 'Grado' 'Bachillerato' 'Bachillerato' 'Bachillerato'
#  'Bachillerato' 'Master' 'Grado' 'Bachillerato' 'Doctorado' 'Doctorado'
#  'Secundaria' 'Bachillerato' 'Grado' 'Grado' 'Master' 'Doctorado'
#  'Secundaria' 'Secundaria' 'Doctorado' 'Master' 'Bachillerato'
#  'Bachillerato' 'Grado' 'Bachillerato']

# %%
# DIAGRAMA DE BARRAS
import matplotlib.pyplot as plt
import numpy as np

# %%
# Obtener los valores únicos de la lista "nivel_estudios"
# y contar cuántas veces aparece cada uno
estudios, frecuencia = np.unique(nivel_estudios, return_counts=True)

print(estudios, frecuencia)

# %%
# Asignar una etiqueta al eje Y (vertical)
plt.ylabel('Frecuencia absoluta')

# Asignar una etiqueta al eje X (horizontal)
plt.xlabel('Nivel de estudios')

# Agregar un título al gráfico
plt.title('Diagrama de barras')

# Crear un gráfico de barras
# "estudios" contiene las categorías del eje X
# "frecuencia" contiene la cantidad de registros de cada categoría
plt.bar(estudios, frecuencia)

# Mostrar el gráfico en pantalla
plt.show()

# %%
# DIAGRAMA DE SECTORES (GRÁFICO CIRCULAR)

# Definir los colores que tendrá cada sector del gráfico
colores = {'red', 'blue', 'orange', 'green', 'cyan'}

# Crear el gráfico circular
# frecuencia: tamaño de cada sector
# labels: nombres de cada categoría
# colors: colores asignados a cada sector
# autopct: muestra el porcentaje con dos decimales

plt.pie(frecuencia, labels=estudios, colors=colores, autopct='%1.2f%%')

plt.title('Diagrama de sectores')


plt.show()

# %% [markdown]
# 1. Crear el DataFrame

# %%
# Importar las librerías necesarias
import pandas as pd
import matplotlib.pyplot as plt

# Crear un DataFrame con los niveles de estudio y sus frecuencias
df = pd.DataFrame({
    'Nivel de estudios': ['Secundaria', 'Bachillerato', 'Grado', 'Master', 'Doctorado'],
    'Frecuencia': [110, 172, 145, 52, 21]
})

print(df)

# %% [markdown]
# 2. Diagrama de barras

# %%
# Crear un gráfico de barras utilizando el DataFrame
plt.bar(df['Nivel de estudios'], df['Frecuencia'])

# Agregar una etiqueta al eje X
plt.xlabel('Nivel de estudios')

# Agregar una etiqueta al eje Y
plt.ylabel('Frecuencia absoluta')

plt.title('Diagrama de barras')

plt.show()

# %% [markdown]
# 3. Diagrama de sectores (pastel)

# %%
# Definir los colores para cada sector del gráfico
colores = ['red', 'blue', 'orange', 'green', 'cyan']

# Crear el gráfico de sectores utilizando el DataFrame
plt.pie(
    df['Frecuencia'],
    labels=df['Nivel de estudios'],
    colors=colores,
    autopct='%1.2f%%'
)

plt.title('Diagrama de sectores')

plt.show()
